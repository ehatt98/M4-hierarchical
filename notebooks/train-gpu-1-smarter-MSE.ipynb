# %%
### misc
import pandas as pd
import numpy as np
import os
from pathlib import Path
import pickle
import time
from itertools import product

#### graphical
import matplotlib.pyplot as plt
import corner

#### ML
import sklearn
from sklearn.decomposition import PCA
import tensorflow as tf
import keras
from keras import layers


##### poke gpu
os.environ["CUDA_VISIBLE_DEVICES"]="1"

physical_devices = tf.config.list_physical_devices("GPU") 

tf.config.experimental.set_memory_growth(physical_devices[0], True)

gpu0usage = tf.config.experimental.get_memory_info("GPU:0")["current"]

print("Current GPU usage:\n"
     + " - GPU0: " + str(gpu0usage) + "B\n")

modelpath = '/home/hatte/M4/models'
# Out:
# 2025-04-01 09:39:46.098628: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743496786.110219 1771407 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743496786.113692 1771407 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-01 09:39:46.126562: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Current GPU usage:
#  - GPU0: 0B
# I0000 00:00:1743496787.516702 1771407 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14135 MB memory:  -> device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
def scheduler(epoch, lr,):
    ## Learning rate scheduler
    # Decreases learning rate in-training for stability
    if lr < 1e-4:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-1e-5))

# %%
df_full = pd.read_hdf('../grids/Chiara.hdf5', key='df') ## edit for your grid!!

df_full['logLPhot'] = np.log10(df_full['LPhot'])

df_full['lognumax'] = np.log10(df_full['numax']*3090)

df_full['logdnuSer'] = np.log10(df_full['dnuSer']*135)

#### define inputs
inputs = ['massini', 'zini', 'yini', 'alphaMLT', 'age', 'eta', 'alphaFe']

#### define outputs
classical_outputs = ['FeH', 'logLPhot', 'Teff']
astero_outputs = ['lognumax', 'logdnuSer'] 

outputs = classical_outputs+astero_outputs

df = df_full[inputs+outputs]

df_norm = (df - df.min())/(df.max() - df.min())

## check df_norm.describe looks reasonable (min=0, max=1):
df_norm.describe()

#### train/test split with seed 
seed = 42

df_train = df_norm.sample(frac=0.95, random_state=seed)
df_test = df_norm.drop(df_train.index)

df_train_inputs, df_val_inputs, df_train_outputs, df_val_outputs = sklearn.model_selection.train_test_split(df_train[inputs],df_train[outputs], test_size = 0.05, random_state=seed)

print("Training set: ", len(df_train_inputs))
print("Validation set: ", len(df_val_inputs))
print("Test set: ", len(df_test))
# Out:
# Training set:  6754081
# Validation set:  355478
# Test set:  374187

# %%
n_dense_layers = 2

dense_layer_units = 512

Nepochs = 5000

learning_rate = 0.001

model_name = 'smart-logLPhot-lognumax-logdnuSer-exponent-1e-5'

loss_func = 'MSE'

df_train_inputs.join(df_train_outputs).to_hdf(f'{modelpath}/long-runs/training-data/training-{model_name}-nlayers-{n_dense_layers}-nunits-{dense_layer_units}-epochs-{Nepochs}-lrate-{learning_rate}-lossfunc-{loss_func}.hdf5', key = 'df')

# %%
checkpoint_dir = f'{modelpath}/long-runs/checkpoint/chk-{model_name}-nlayers-{n_dense_layers}-nunits-{dense_layer_units}-epochs-{Nepochs}-lrate-{learning_rate}-lossfunc-{loss_func}.model.keras'

full_model_dir = f'{modelpath}/long-runs/full-model/mod-{model_name}-nlayers-{n_dense_layers}-nunits-{dense_layer_units}-epochs-{Nepochs}-lrate-{learning_rate}-lossfunc-{loss_func}/'

if not os.path.exists(full_model_dir):
    os.makedirs(full_model_dir)

historyfile = f'{modelpath}/long-runs/history/hist-{model_name}-nlayers-{n_dense_layers}-nunits-{dense_layer_units}-epochs-{Nepochs}-lrate-{learning_rate}-lossfunc-{loss_func}.json'
    
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_dir, verbose = 1, save_best_only = True, save_freq = 'epoch')

lr_callback = tf.keras.callbacks.LearningRateScheduler(scheduler, )

# %%
######## map out model architecture
#### input layer
nn_input = keras.Input(shape=(len(inputs),))

#### dense layer(s)
for n_dense_layer in range(n_dense_layers):
    if n_dense_layer == 0:
        dense_layer = layers.Dense(dense_layer_units, activation='relu')(nn_input)
    else:
        dense_layer = layers.Dense(dense_layer_units, activation='relu')(dense_layer)

#### output layer
nn_output =  layers.Dense(len(outputs), activation='linear')(dense_layer)

######## store architecture as keras model
model = keras.Model(inputs=nn_input, outputs=nn_output, name=model_name)

tb_callback = tf.keras.callbacks.TensorBoard(log_dir = f'{modelpath}/logs/long-runs/log-{model_name}-nlayers-{n_dense_layers}-nunits-{dense_layer_units}-epochs-{Nepochs}-lrate-{learning_rate}-lossfunc-{loss_func}')

model.compile(loss='MSE', optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

history = model.fit(df_train_inputs,
          df_train_outputs,
          validation_data=(df_val_inputs,df_val_outputs),
          batch_size=2**16, #change higher
          verbose=1,
          epochs=Nepochs,
          shuffle=True, callbacks = [tb_callback, cp_callback, lr_callback]) 

tf.saved_model.save(model, full_model_dir)
hist_df = pd.DataFrame(history.history)
    
with open(os.path.join(modelpath, historyfile), mode="w") as f:
    hist_df.to_json(f)
# Out:
# Epoch 1/5000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743496799.067258 1771852 service.cc:148] XLA service 0x75e4ed00a8d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743496799.067289 1771852 service.cc:156]   StreamExecutor device (0): NVIDIA RTX A4500, Compute Capability 8.6
# 2025-04-01 09:39:59.086180: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1743496799.142910 1771852 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-04-01 09:39:59.217537: W external/local_xla/xla/service/gpu/nvptx_compiler.cc:930] The NVIDIA driver's CUDA version is 12.2 which is older than the PTX compiler version 12.8.61. Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# 2025-04-01 09:39:59.776649: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_164', 188 bytes spill stores, 188 bytes spill loads
#
# 2025-04-01 09:39:59.947046: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-04-01 09:39:59.985135: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_164', 760 bytes spill stores, 708 bytes spill loads
#
# 2025-04-01 09:40:00.116209: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_323', 112 bytes spill stores, 108 bytes spill loads
#
# 2025-04-01 09:40:00.208292: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321_0', 664 bytes spill stores, 636 bytes spill loads
#
# 2025-04-01 09:40:00.262361: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_323', 4748 bytes spill stores, 4736 bytes spill loads
#
# 2025-04-01 09:40:00.300179: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-04-01 09:40:00.308989: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_323', 3400 bytes spill stores, 3404 bytes spill loads
#  14/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1138
# I0000 00:00:1743496801.167000 1771852 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0570
# 2025-04-01 09:40:02.625858: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_164', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-04-01 09:40:02.794158: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321', 56 bytes spill stores, 56 bytes spill loads
#
# 2025-04-01 09:40:02.845047: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321', 168 bytes spill stores, 168 bytes spill loads
#
# 2025-04-01 09:40:02.965916: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321', 276 bytes spill stores, 276 bytes spill loads
#
# 2025-04-01 09:40:02.975472: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-04-01 09:40:02.982382: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_164_0', 756 bytes spill stores, 444 bytes spill loads
#
# 2025-04-01 09:40:02.991518: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_323', 544 bytes spill stores, 544 bytes spill loads
#
# 2025-04-01 09:40:03.140365: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-04-01 09:40:03.166815: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321', 128 bytes spill stores, 128 bytes spill loads
#
# 2025-04-01 09:40:03.171787: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_323', 412 bytes spill stores, 416 bytes spill loads
#
# 2025-04-01 09:40:03.387731: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_323', 4048 bytes spill stores, 4048 bytes spill loads
#
# 2025-04-01 09:40:03.426823: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_321_0', 760 bytes spill stores, 784 bytes spill loads
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0559
# 2025-04-01 09:40:04.916979: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 196 bytes spill stores, 196 bytes spill loads
#
# 2025-04-01 09:40:05.108026: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 740 bytes spill stores, 436 bytes spill loads
# Epoch 1: val_loss improved from inf to 0.02750, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 0.0557 - val_loss: 0.0275 - learning_rate: 9.9999e-04
# Epoch 2/5000
# 101/104 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0271
# Epoch 2: val_loss improved from 0.02750 to 0.02652, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0271 - val_loss: 0.0265 - learning_rate: 9.9998e-04
# Epoch 3/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0265
# Epoch 3: val_loss improved from 0.02652 to 0.02618, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0264 - val_loss: 0.0262 - learning_rate: 9.9997e-04
# Epoch 4/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0261
# Epoch 4: val_loss improved from 0.02618 to 0.02569, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0261 - val_loss: 0.0257 - learning_rate: 9.9996e-04
# Epoch 5/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0256
# Epoch 5: val_loss improved from 0.02569 to 0.02501, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0256 - val_loss: 0.0250 - learning_rate: 9.9995e-04
# Epoch 6/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0251
# Epoch 6: val_loss improved from 0.02501 to 0.02483, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0251 - val_loss: 0.0248 - learning_rate: 9.9994e-04
# Epoch 7/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0244
# Epoch 7: val_loss improved from 0.02483 to 0.02348, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0244 - val_loss: 0.0235 - learning_rate: 9.9993e-04
# Epoch 8/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0236
# Epoch 8: val_loss improved from 0.02348 to 0.02261, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0236 - val_loss: 0.0226 - learning_rate: 9.9992e-04
# Epoch 9/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0232
# Epoch 9: val_loss improved from 0.02261 to 0.02226, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0232 - val_loss: 0.0223 - learning_rate: 9.9991e-04
# Epoch 10/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0220
# Epoch 10: val_loss improved from 0.02226 to 0.02095, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0220 - val_loss: 0.0209 - learning_rate: 9.9990e-04
# Epoch 11/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0216
# Epoch 11: val_loss improved from 0.02095 to 0.01981, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0216 - val_loss: 0.0198 - learning_rate: 9.9989e-04
# Epoch 12/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0201
# Epoch 12: val_loss improved from 0.01981 to 0.01896, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0201 - val_loss: 0.0190 - learning_rate: 9.9988e-04
# Epoch 13/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0192
# Epoch 13: val_loss improved from 0.01896 to 0.01824, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0192 - val_loss: 0.0182 - learning_rate: 9.9987e-04
# Epoch 14/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0192
# Epoch 14: val_loss improved from 0.01824 to 0.01721, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0192 - val_loss: 0.0172 - learning_rate: 9.9986e-04
# Epoch 15/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0174
# Epoch 15: val_loss improved from 0.01721 to 0.01612, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0174 - val_loss: 0.0161 - learning_rate: 9.9985e-04
# Epoch 16/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0179
# Epoch 16: val_loss did not improve from 0.01612
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0179 - val_loss: 0.0162 - learning_rate: 9.9984e-04
# Epoch 17/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0178
# Epoch 17: val_loss improved from 0.01612 to 0.01523, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0178 - val_loss: 0.0152 - learning_rate: 9.9983e-04
# Epoch 18/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 18: val_loss improved from 0.01523 to 0.01393, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0150 - val_loss: 0.0139 - learning_rate: 9.9982e-04
# Epoch 19/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0183
# Epoch 19: val_loss improved from 0.01393 to 0.01369, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0182 - val_loss: 0.0137 - learning_rate: 9.9981e-04
# Epoch 20/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0138
# Epoch 20: val_loss did not improve from 0.01369
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0138 - val_loss: 0.0160 - learning_rate: 9.9980e-04
# Epoch 21/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 21: val_loss did not improve from 0.01369
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0136 - val_loss: 0.0139 - learning_rate: 9.9979e-04
# Epoch 22/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135
# Epoch 22: val_loss improved from 0.01369 to 0.01236, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0135 - val_loss: 0.0124 - learning_rate: 9.9978e-04
# Epoch 23/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125
# Epoch 23: val_loss improved from 0.01236 to 0.01173, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0125 - val_loss: 0.0117 - learning_rate: 9.9977e-04
# Epoch 24/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130
# Epoch 24: val_loss improved from 0.01173 to 0.01139, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0130 - val_loss: 0.0114 - learning_rate: 9.9976e-04
# Epoch 25/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0117
# Epoch 25: val_loss did not improve from 0.01139
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0118 - val_loss: 0.0248 - learning_rate: 9.9975e-04
# Epoch 26/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131
# Epoch 26: val_loss improved from 0.01139 to 0.01042, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0131 - val_loss: 0.0104 - learning_rate: 9.9974e-04
# Epoch 27/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118
# Epoch 27: val_loss did not improve from 0.01042
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0118 - val_loss: 0.0175 - learning_rate: 9.9973e-04
# Epoch 28/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0121
# Epoch 28: val_loss did not improve from 0.01042
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0122 - val_loss: 0.0143 - learning_rate: 9.9972e-04
# Epoch 29/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0108
# Epoch 29: val_loss improved from 0.01042 to 0.00945, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0108 - val_loss: 0.0095 - learning_rate: 9.9971e-04
# Epoch 30/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0107
# Epoch 30: val_loss improved from 0.00945 to 0.00924, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0107 - val_loss: 0.0092 - learning_rate: 9.9970e-04
# Epoch 31/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 31: val_loss did not improve from 0.00924
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0109 - val_loss: 0.0096 - learning_rate: 9.9969e-04
# Epoch 32/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112
# Epoch 32: val_loss improved from 0.00924 to 0.00888, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0112 - val_loss: 0.0089 - learning_rate: 9.9968e-04
# Epoch 33/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112
# Epoch 33: val_loss improved from 0.00888 to 0.00847, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0112 - val_loss: 0.0085 - learning_rate: 9.9967e-04
# Epoch 34/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0128
# Epoch 34: val_loss did not improve from 0.00847
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0127 - val_loss: 0.0086 - learning_rate: 9.9966e-04
# Epoch 35/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0103
# Epoch 35: val_loss did not improve from 0.00847
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0103 - val_loss: 0.0106 - learning_rate: 9.9965e-04
# Epoch 36/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115
# Epoch 36: val_loss did not improve from 0.00847
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0115 - val_loss: 0.0085 - learning_rate: 9.9964e-04
# Epoch 37/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097
# Epoch 37: val_loss improved from 0.00847 to 0.00836, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0099 - val_loss: 0.0084 - learning_rate: 9.9963e-04
# Epoch 38/5000
#  99/104 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0081
# Epoch 38: val_loss did not improve from 0.00836
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0081 - val_loss: 0.0249 - learning_rate: 9.9962e-04
# Epoch 39/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0108
# Epoch 39: val_loss improved from 0.00836 to 0.00814, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0108 - val_loss: 0.0081 - learning_rate: 9.9961e-04
# Epoch 40/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 40: val_loss did not improve from 0.00814
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0083 - val_loss: 0.0087 - learning_rate: 9.9960e-04
# Epoch 41/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 41: val_loss improved from 0.00814 to 0.00762, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0083 - val_loss: 0.0076 - learning_rate: 9.9959e-04
# Epoch 42/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 42: val_loss improved from 0.00762 to 0.00733, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0087 - val_loss: 0.0073 - learning_rate: 9.9958e-04
# Epoch 43/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0108
# Epoch 43: val_loss improved from 0.00733 to 0.00710, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0108 - val_loss: 0.0071 - learning_rate: 9.9957e-04
# Epoch 44/5000
#  99/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 44: val_loss did not improve from 0.00710
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0087 - val_loss: 0.0080 - learning_rate: 9.9956e-04
# Epoch 45/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0105
# Epoch 45: val_loss did not improve from 0.00710
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0105 - val_loss: 0.0089 - learning_rate: 9.9955e-04
# Epoch 46/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 46: val_loss did not improve from 0.00710
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0077 - val_loss: 0.0090 - learning_rate: 9.9954e-04
# Epoch 47/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0116
# Epoch 47: val_loss improved from 0.00710 to 0.00692, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0115 - val_loss: 0.0069 - learning_rate: 9.9953e-04
# Epoch 48/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 48: val_loss did not improve from 0.00692
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0088 - val_loss: 0.0076 - learning_rate: 9.9952e-04
# Epoch 49/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079
# Epoch 49: val_loss improved from 0.00692 to 0.00685, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - val_loss: 0.0068 - learning_rate: 9.9951e-04
# Epoch 50/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0111
# Epoch 50: val_loss did not improve from 0.00685
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0109 - val_loss: 0.0076 - learning_rate: 9.9950e-04
# Epoch 51/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135
# Epoch 51: val_loss improved from 0.00685 to 0.00639, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0133 - val_loss: 0.0064 - learning_rate: 9.9949e-04
# Epoch 52/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 52: val_loss did not improve from 0.00639
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 0.0065 - learning_rate: 9.9948e-04
# Epoch 53/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085
# Epoch 53: val_loss did not improve from 0.00639
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0085 - val_loss: 0.0068 - learning_rate: 9.9948e-04
# Epoch 54/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 54: val_loss did not improve from 0.00639
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - val_loss: 0.0126 - learning_rate: 9.9947e-04
# Epoch 55/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0101
# Epoch 55: val_loss did not improve from 0.00639
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0101 - val_loss: 0.0072 - learning_rate: 9.9946e-04
# Epoch 56/5000
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065
# Epoch 56: val_loss did not improve from 0.00639
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0065 - val_loss: 0.0140 - learning_rate: 9.9945e-04
# Epoch 57/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 57: val_loss improved from 0.00639 to 0.00613, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0109 - val_loss: 0.0061 - learning_rate: 9.9944e-04
# Epoch 58/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 58: val_loss did not improve from 0.00613
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0076 - val_loss: 0.0070 - learning_rate: 9.9943e-04
# Epoch 59/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096
# Epoch 59: val_loss did not improve from 0.00613
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0125 - learning_rate: 9.9942e-04
# Epoch 60/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 60: val_loss did not improve from 0.00613
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0074 - val_loss: 0.0065 - learning_rate: 9.9941e-04
# Epoch 61/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 61: val_loss improved from 0.00613 to 0.00595, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 0.0059 - learning_rate: 9.9940e-04
# Epoch 62/5000
# 101/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 62: val_loss did not improve from 0.00595
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0069 - val_loss: 0.0066 - learning_rate: 9.9939e-04
# Epoch 63/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093
# Epoch 63: val_loss improved from 0.00595 to 0.00591, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0093 - val_loss: 0.0059 - learning_rate: 9.9938e-04
# Epoch 64/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 64: val_loss did not improve from 0.00591
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0070 - val_loss: 0.0059 - learning_rate: 9.9937e-04
# Epoch 65/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 65: val_loss did not improve from 0.00591
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0062 - val_loss: 0.0060 - learning_rate: 9.9936e-04
# Epoch 66/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064
# Epoch 66: val_loss did not improve from 0.00591
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0064 - val_loss: 0.0075 - learning_rate: 9.9935e-04
# Epoch 67/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 67: val_loss improved from 0.00591 to 0.00558, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0077 - val_loss: 0.0056 - learning_rate: 9.9934e-04
# Epoch 68/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 68: val_loss improved from 0.00558 to 0.00551, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0076 - val_loss: 0.0055 - learning_rate: 9.9933e-04
# Epoch 69/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 69: val_loss did not improve from 0.00551
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066 - val_loss: 0.0056 - learning_rate: 9.9932e-04
# Epoch 70/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065
# Epoch 70: val_loss improved from 0.00551 to 0.00536, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0065 - val_loss: 0.0054 - learning_rate: 9.9931e-04
# Epoch 71/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 71: val_loss did not improve from 0.00536
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0076 - val_loss: 0.0055 - learning_rate: 9.9930e-04
# Epoch 72/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 72: val_loss improved from 0.00536 to 0.00530, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0061 - val_loss: 0.0053 - learning_rate: 9.9929e-04
# Epoch 73/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0098
# Epoch 73: val_loss did not improve from 0.00530
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0096 - val_loss: 0.0053 - learning_rate: 9.9928e-04
# Epoch 74/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0086
# Epoch 74: val_loss did not improve from 0.00530
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0085 - val_loss: 0.0058 - learning_rate: 9.9927e-04
# Epoch 75/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092
# Epoch 75: val_loss did not improve from 0.00530
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0092 - val_loss: 0.0167 - learning_rate: 9.9926e-04
# Epoch 76/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 76: val_loss did not improve from 0.00530
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0080 - val_loss: 0.0058 - learning_rate: 9.9925e-04
# Epoch 77/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109
# Epoch 77: val_loss improved from 0.00530 to 0.00523, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0109 - val_loss: 0.0052 - learning_rate: 9.9924e-04
# Epoch 78/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0098
# Epoch 78: val_loss did not improve from 0.00523
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0096 - val_loss: 0.0053 - learning_rate: 9.9923e-04
# Epoch 79/5000
# 101/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 79: val_loss did not improve from 0.00523
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0084 - val_loss: 0.0062 - learning_rate: 9.9922e-04
# Epoch 80/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059
# Epoch 80: val_loss did not improve from 0.00523
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0060 - val_loss: 0.0057 - learning_rate: 9.9921e-04
# Epoch 81/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 81: val_loss did not improve from 0.00523
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0062 - val_loss: 0.0053 - learning_rate: 9.9920e-04
# Epoch 82/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 82: val_loss improved from 0.00523 to 0.00488, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0062 - val_loss: 0.0049 - learning_rate: 9.9919e-04
# Epoch 83/5000
#  99/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072
# Epoch 83: val_loss did not improve from 0.00488
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0073 - val_loss: 0.0061 - learning_rate: 9.9918e-04
# Epoch 84/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 84: val_loss did not improve from 0.00488
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - val_loss: 0.0059 - learning_rate: 9.9917e-04
# Epoch 85/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053
# Epoch 85: val_loss did not improve from 0.00488
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0053 - val_loss: 0.0099 - learning_rate: 9.9916e-04
# Epoch 86/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0121
# Epoch 86: val_loss improved from 0.00488 to 0.00487, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0120 - val_loss: 0.0049 - learning_rate: 9.9915e-04
# Epoch 87/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 87: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0087 - val_loss: 0.0067 - learning_rate: 9.9914e-04
# Epoch 88/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072
# Epoch 88: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - val_loss: 0.0214 - learning_rate: 9.9913e-04
# Epoch 89/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 89: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0075 - val_loss: 0.0055 - learning_rate: 9.9912e-04
# Epoch 90/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065
# Epoch 90: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066 - val_loss: 0.0052 - learning_rate: 9.9911e-04
# Epoch 91/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054
# Epoch 91: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0055 - val_loss: 0.0051 - learning_rate: 9.9910e-04
# Epoch 92/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 92: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0061 - val_loss: 0.0361 - learning_rate: 9.9909e-04
# Epoch 93/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0092
# Epoch 93: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0091 - val_loss: 0.0108 - learning_rate: 9.9908e-04
# Epoch 94/5000
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 94: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0060 - val_loss: 0.0067 - learning_rate: 9.9907e-04
# Epoch 95/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 95: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0076 - val_loss: 0.0049 - learning_rate: 9.9906e-04
# Epoch 96/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097
# Epoch 96: val_loss did not improve from 0.00487
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0096 - val_loss: 0.0056 - learning_rate: 9.9905e-04
# Epoch 97/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 97: val_loss improved from 0.00487 to 0.00486, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0069 - val_loss: 0.0049 - learning_rate: 9.9904e-04
# Epoch 98/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064
# Epoch 98: val_loss did not improve from 0.00486
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066 - val_loss: 0.0060 - learning_rate: 9.9903e-04
# Epoch 99/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054
# Epoch 99: val_loss did not improve from 0.00486
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0054 - val_loss: 0.0050 - learning_rate: 9.9902e-04
# Epoch 100/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 100: val_loss improved from 0.00486 to 0.00467, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0060 - val_loss: 0.0047 - learning_rate: 9.9901e-04
# Epoch 101/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 101: val_loss improved from 0.00467 to 0.00431, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066 - val_loss: 0.0043 - learning_rate: 9.9900e-04
# Epoch 102/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0080
# Epoch 102: val_loss did not improve from 0.00431
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - val_loss: 0.0225 - learning_rate: 9.9899e-04
# Epoch 103/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 103: val_loss did not improve from 0.00431
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 0.0044 - learning_rate: 9.9898e-04
# Epoch 104/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056
# Epoch 104: val_loss did not improve from 0.00431
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0057 - val_loss: 0.0045 - learning_rate: 9.9897e-04
# Epoch 105/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 105: val_loss did not improve from 0.00431
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0069 - val_loss: 0.0045 - learning_rate: 9.9896e-04
# Epoch 106/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 106: val_loss did not improve from 0.00431
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - val_loss: 0.0070 - learning_rate: 9.9895e-04
# Epoch 107/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058
# Epoch 107: val_loss improved from 0.00431 to 0.00420, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - val_loss: 0.0042 - learning_rate: 9.9894e-04
# Epoch 108/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 108: val_loss improved from 0.00420 to 0.00417, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0070 - val_loss: 0.0042 - learning_rate: 9.9893e-04
# Epoch 109/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057
# Epoch 109: val_loss improved from 0.00417 to 0.00407, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0057 - val_loss: 0.0041 - learning_rate: 9.9892e-04
# Epoch 110/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087
# Epoch 110: val_loss did not improve from 0.00407
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0086 - val_loss: 0.0078 - learning_rate: 9.9891e-04
# Epoch 111/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0068
# Epoch 111: val_loss did not improve from 0.00407
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0068 - val_loss: 0.0045 - learning_rate: 9.9890e-04
# Epoch 112/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059
# Epoch 112: val_loss did not improve from 0.00407
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0059 - val_loss: 0.0041 - learning_rate: 9.9889e-04
# Epoch 113/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 113: val_loss did not improve from 0.00407
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0071 - val_loss: 0.0043 - learning_rate: 9.9888e-04
# Epoch 114/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053
# Epoch 114: val_loss did not improve from 0.00407
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0054 - val_loss: 0.0042 - learning_rate: 9.9887e-04
# Epoch 115/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 115: val_loss did not improve from 0.00407
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0078 - val_loss: 0.0102 - learning_rate: 9.9886e-04
# Epoch 116/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 116: val_loss improved from 0.00407 to 0.00395, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0062 - val_loss: 0.0039 - learning_rate: 9.9885e-04
# Epoch 117/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063
# Epoch 117: val_loss did not improve from 0.00395
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0063 - val_loss: 0.0044 - learning_rate: 9.9884e-04
# Epoch 118/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059
# Epoch 118: val_loss did not improve from 0.00395
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0059 - val_loss: 0.0187 - learning_rate: 9.9883e-04
# Epoch 119/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 119: val_loss did not improve from 0.00395
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0084 - val_loss: 0.0059 - learning_rate: 9.9882e-04
# Epoch 120/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057
# Epoch 120: val_loss did not improve from 0.00395
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0057 - val_loss: 0.0040 - learning_rate: 9.9881e-04
# Epoch 121/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056
# Epoch 121: val_loss did not improve from 0.00395
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0056 - val_loss: 0.0092 - learning_rate: 9.9880e-04
# Epoch 122/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055
# Epoch 122: val_loss did not improve from 0.00395
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0055 - val_loss: 0.0085 - learning_rate: 9.9879e-04
# Epoch 123/5000
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 123: val_loss did not improve from 0.00395
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066 - val_loss: 0.0061 - learning_rate: 9.9878e-04
# Epoch 124/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057
# Epoch 124: val_loss did not improve from 0.00395
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - val_loss: 0.0041 - learning_rate: 9.9877e-04
# Epoch 125/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063
# Epoch 125: val_loss improved from 0.00395 to 0.00378, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0063 - val_loss: 0.0038 - learning_rate: 9.9876e-04
# Epoch 126/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 126: val_loss did not improve from 0.00378
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0070 - val_loss: 0.0039 - learning_rate: 9.9875e-04
# Epoch 127/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056
# Epoch 127: val_loss did not improve from 0.00378
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0056 - val_loss: 0.0038 - learning_rate: 9.9874e-04
# Epoch 128/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063
# Epoch 128: val_loss did not improve from 0.00378
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0063 - val_loss: 0.0041 - learning_rate: 9.9873e-04
# Epoch 129/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064
# Epoch 129: val_loss did not improve from 0.00378
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0064 - val_loss: 0.0044 - learning_rate: 9.9872e-04
# Epoch 130/5000
#  99/104 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0053
# Epoch 130: val_loss did not improve from 0.00378
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0053 - val_loss: 0.0049 - learning_rate: 9.9871e-04
# Epoch 131/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 131: val_loss improved from 0.00378 to 0.00368, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0061 - val_loss: 0.0037 - learning_rate: 9.9870e-04
# Epoch 132/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 132: val_loss improved from 0.00368 to 0.00367, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066 - val_loss: 0.0037 - learning_rate: 9.9869e-04
# Epoch 133/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0086
# Epoch 133: val_loss did not improve from 0.00367
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0085 - val_loss: 0.0048 - learning_rate: 9.9868e-04
# Epoch 134/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063
# Epoch 134: val_loss did not improve from 0.00367
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0063 - val_loss: 0.0037 - learning_rate: 9.9867e-04
# Epoch 135/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 135: val_loss improved from 0.00367 to 0.00364, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0062 - val_loss: 0.0036 - learning_rate: 9.9866e-04
# Epoch 136/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052
# Epoch 136: val_loss did not improve from 0.00364
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0052 - val_loss: 0.0058 - learning_rate: 9.9865e-04
# Epoch 137/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059
# Epoch 137: val_loss did not improve from 0.00364
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0059 - val_loss: 0.0056 - learning_rate: 9.9864e-04
# Epoch 138/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050
# Epoch 138: val_loss improved from 0.00364 to 0.00359, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0050 - val_loss: 0.0036 - learning_rate: 9.9863e-04
# Epoch 139/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 139: val_loss did not improve from 0.00359
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0086 - val_loss: 0.0037 - learning_rate: 9.9862e-04
# Epoch 140/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054
# ...
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0030 - learning_rate: 9.9202e-04
# Epoch 807/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 807: val_loss did not improve from 0.00111
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0027 - val_loss: 0.0015 - learning_rate: 9.9201e-04
# Epoch 808/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 808: val_loss did not improve from 0.00111
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0065 - learning_rate: 9.9200e-04
# Epoch 809/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 809: val_loss did not improve from 0.00111
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0027 - val_loss: 0.0019 - learning_rate: 9.9199e-04
# Epoch 810/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 810: val_loss improved from 0.00111 to 0.00111, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0028 - val_loss: 0.0011 - learning_rate: 9.9198e-04
# Epoch 811/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 811: val_loss did not improve from 0.00111
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024 - val_loss: 0.0048 - learning_rate: 9.9197e-04
# Epoch 812/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 812: val_loss did not improve from 0.00111
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0027 - val_loss: 0.0020 - learning_rate: 9.9196e-04
# Epoch 813/5000
# 100/104 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 813: val_loss did not improve from 0.00111
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0026 - val_loss: 0.0070 - learning_rate: 9.9195e-04
# Epoch 814/5000
#  99/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 814: val_loss did not improve from 0.00111
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030 - val_loss: 0.0011 - learning_rate: 9.9194e-04
# Epoch 815/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 815: val_loss improved from 0.00111 to 0.00110, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - val_loss: 0.0011 - learning_rate: 9.9193e-04
# Epoch 816/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034
# Epoch 816: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0034 - val_loss: 0.0028 - learning_rate: 9.9192e-04
# Epoch 817/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 817: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0015 - learning_rate: 9.9192e-04
# Epoch 818/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 818: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0023 - val_loss: 0.0059 - learning_rate: 9.9191e-04
# Epoch 819/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 819: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0028 - val_loss: 0.0016 - learning_rate: 9.9190e-04
# Epoch 820/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 820: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - val_loss: 0.0052 - learning_rate: 9.9189e-04
# Epoch 821/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036
# Epoch 821: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035 - val_loss: 0.0014 - learning_rate: 9.9188e-04
# Epoch 822/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 822: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0014 - learning_rate: 9.9187e-04
# Epoch 823/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 823: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - val_loss: 0.0029 - learning_rate: 9.9186e-04
# Epoch 824/5000
# 101/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 824: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0063 - learning_rate: 9.9185e-04
# Epoch 825/5000
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# Epoch 825: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0011 - learning_rate: 9.9184e-04
# Epoch 826/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 826: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - val_loss: 0.0013 - learning_rate: 9.9183e-04
# Epoch 827/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038
# Epoch 827: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0037 - val_loss: 0.0015 - learning_rate: 9.9182e-04
# Epoch 828/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 828: val_loss did not improve from 0.00110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0031 - val_loss: 0.0011 - learning_rate: 9.9181e-04
# Epoch 829/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 829: val_loss improved from 0.00110 to 0.00106, saving model to /home/hatte/M4/models/long-runs/checkpoint/chk-smart-logLPhot-lognumax-logdnuSer-exponent-1e-5-nlayers-2-nunits-512-epochs-5000-lrate-0.001-lossfunc-MSE.model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - val_loss: 0.0011 - learning_rate: 9.9180e-04
# Epoch 830/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035
# Epoch 830: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0035 - val_loss: 0.0019 - learning_rate: 9.9179e-04
# Epoch 831/5000
# 100/104 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024
# Epoch 831: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0025 - val_loss: 0.0025 - learning_rate: 9.9178e-04
# Epoch 832/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 832: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - val_loss: 0.0045 - learning_rate: 9.9177e-04
# Epoch 833/5000
#  99/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 833: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0029 - val_loss: 0.0024 - learning_rate: 9.9176e-04
# Epoch 834/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 834: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030 - val_loss: 0.0032 - learning_rate: 9.9175e-04
# Epoch 835/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 835: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0023 - val_loss: 0.0069 - learning_rate: 9.9174e-04
# Epoch 836/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 836: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0038 - learning_rate: 9.9173e-04
# Epoch 837/5000
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 837: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0012 - learning_rate: 9.9172e-04
# Epoch 838/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 838: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0025 - val_loss: 0.0012 - learning_rate: 9.9171e-04
# Epoch 839/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021
# Epoch 839: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - val_loss: 0.0019 - learning_rate: 9.9170e-04
# Epoch 840/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 840: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0031 - learning_rate: 9.9169e-04
# Epoch 841/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 841: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0028 - val_loss: 0.0019 - learning_rate: 9.9168e-04
# Epoch 842/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 842: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0027 - val_loss: 0.0012 - learning_rate: 9.9167e-04
# Epoch 843/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 843: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - val_loss: 0.0023 - learning_rate: 9.9166e-04
# Epoch 844/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 844: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0025 - val_loss: 0.0014 - learning_rate: 9.9165e-04
# Epoch 845/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021
# Epoch 845: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - val_loss: 0.0025 - learning_rate: 9.9164e-04
# Epoch 846/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 846: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0026 - learning_rate: 9.9163e-04
# Epoch 847/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 847: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0025 - val_loss: 0.0016 - learning_rate: 9.9162e-04
# Epoch 848/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 848: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0028 - val_loss: 0.0035 - learning_rate: 9.9161e-04
# Epoch 849/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 849: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0028 - val_loss: 0.0033 - learning_rate: 9.9160e-04
# Epoch 850/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023
# Epoch 850: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023 - val_loss: 0.0017 - learning_rate: 9.9159e-04
# Epoch 851/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 851: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024 - val_loss: 0.0018 - learning_rate: 9.9158e-04
# Epoch 852/5000
# 100/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 852: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0023 - val_loss: 0.0013 - learning_rate: 9.9157e-04
# Epoch 853/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034
# Epoch 853: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0034 - val_loss: 0.0022 - learning_rate: 9.9156e-04
# Epoch 854/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 854: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 0.0013 - learning_rate: 9.9155e-04
# Epoch 855/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 855: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024 - val_loss: 0.0158 - learning_rate: 9.9154e-04
# Epoch 856/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042
# Epoch 856: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0041 - val_loss: 0.0019 - learning_rate: 9.9153e-04
# Epoch 857/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 857: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - val_loss: 0.0026 - learning_rate: 9.9152e-04
# Epoch 858/5000
#  99/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 858: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - val_loss: 0.0017 - learning_rate: 9.9151e-04
# Epoch 859/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 859: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0028 - val_loss: 0.0022 - learning_rate: 9.9150e-04
# Epoch 860/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 860: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0014 - learning_rate: 9.9149e-04
# Epoch 861/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 861: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - val_loss: 0.0033 - learning_rate: 9.9148e-04
# Epoch 862/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 862: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0023 - val_loss: 0.0023 - learning_rate: 9.9147e-04
# Epoch 863/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 863: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0056 - learning_rate: 9.9146e-04
# Epoch 864/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041
# Epoch 864: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0040 - val_loss: 0.0013 - learning_rate: 9.9145e-04
# Epoch 865/5000
#  99/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 865: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - val_loss: 0.0011 - learning_rate: 9.9144e-04
# Epoch 866/5000
# 101/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034
# Epoch 866: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0033 - val_loss: 0.0013 - learning_rate: 9.9143e-04
# Epoch 867/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 867: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0025 - val_loss: 0.0020 - learning_rate: 9.9142e-04
# Epoch 868/5000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030
# Epoch 868: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0030 - val_loss: 0.0019 - learning_rate: 9.9141e-04
# Epoch 869/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 869: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024 - val_loss: 0.0024 - learning_rate: 9.9140e-04
# Epoch 870/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 870: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 0.0021 - learning_rate: 9.9139e-04
# Epoch 871/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 871: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0025 - val_loss: 0.0018 - learning_rate: 9.9138e-04
# Epoch 872/5000
#  98/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 872: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0025 - val_loss: 0.0011 - learning_rate: 9.9137e-04
# Epoch 873/5000
#  97/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042
# Epoch 873: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0041 - val_loss: 0.0031 - learning_rate: 9.9136e-04
# Epoch 874/5000
# 101/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 874: val_loss did not improve from 0.00106
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0026 - val_loss: 0.0013 - learning_rate: 9.9135e-04
# Epoch 875/5000
#  90/104 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022

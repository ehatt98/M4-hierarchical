# %% [markdown]
# # Emulator Tests

# %%
#### misc
import pandas as pd
import numpy as np
import os
from pathlib import Path
import pickle
import time
from itertools import product

#### graphical
import matplotlib.pyplot as plt
import corner

#### ML
import sklearn
from sklearn.decomposition import PCA
import tensorflow as tf
import keras
from keras import layers

##### poke gpu
os.environ["CUDA_VISIBLE_DEVICES"]="0"

physical_devices = tf.config.list_physical_devices("GPU") 

gpu0usage = tf.config.experimental.get_memory_info("GPU:0")["current"]

print("Current GPU usage:\n"
     + " - GPU0: " + str(gpu0usage) + "B\n")
# Out:
# Current GPU usage:
#  - GPU0: 752090368B

# %% [markdown]
# ## data prep
# usually called 'data augmentation' in the ML community, but I think referees will have questions if you say "we augmented the data to make our network train better" - this is where we get our data ready for a neural network to start training.\
# usually consists of:
# - check and clean data to remove NaNs etc
# - define our inputs and outputs for training
# - scale data for better network training
# - split into our *train*, *validation*, and *test* sets

# %% [markdown]
# ### inps, outs and normalise

# %%
df_full = pd.read_hdf('../grids/Chiara.hdf5', key='df') ## edit for your grid!!

#### define inputs
inputs = ['massini', 'zini', 'yini', 'alphaMLT', 'age', 'eta', 'alphaFe']

#### define outputs
classical_outputs = ['FeH', 'LPhot', 'Teff']
astero_outputs = ['numax', 'dnuSer'] # 10 modes for now

outputs = classical_outputs+astero_outputs

df = df_full[inputs+outputs]

df_norm = (df - df.min())/(df.max() - df.min())

## check df_norm.describe looks reasonable (min=0, max=1):
df_norm.describe()
# Out:
#             massini          zini          yini      alphaMLT           age  \
# count  7.483746e+06  7.483746e+06  7.483746e+06  7.483746e+06  7.483746e+06
# mean   5.320517e-01  1.169785e-01  4.801320e-01  5.207879e-01  2.894701e-01
# std    2.741396e-01  1.503168e-01  2.866208e-01  2.874298e-01  2.407603e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.050000e-01  1.490123e-02  2.313656e-01  2.751358e-01  1.004077e-01
# 50%    5.362500e-01  5.506925e-02  4.703010e-01  5.304316e-01  2.083946e-01
# 75%    7.675000e-01  1.620700e-01  7.242537e-01  7.715646e-01  4.200869e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                 eta       alphaFe           FeH         LPhot          Teff  \
# count  7.483746e+06  7.483746e+06  7.483746e+06  7.483746e+06  7.483746e+06
# mean   4.995957e-01  5.104678e-01  5.510095e-01  2.481507e-01  1.893095e-01
# std    2.886541e-01  3.224309e-01  2.766927e-01  1.738870e-01  6.669141e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.494505e-01  2.500000e-01  3.284310e-01  1.053661e-01  1.458403e-01
# 50%    4.997558e-01  5.000000e-01  5.743831e-01  2.169322e-01  1.897028e-01
# 75%    7.497558e-01  7.500000e-01  7.868256e-01  3.606867e-01  2.266111e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#               numax        dnuSer
# count  7.483746e+06  7.483746e+06
# mean   8.156236e-02  1.211709e-01
# std    1.351872e-01  1.753661e-01
# min    0.000000e+00  0.000000e+00
# 25%    1.179608e-02  1.922842e-02
# 50%    2.948648e-02  5.268312e-02
# 75%    8.206797e-02  1.401112e-01
# max    1.000000e+00  1.000000e+00

# %% [markdown]
# ### split into train/validate/test

# %%
#### train/test split with seed 
seed = 42

df_train = df_norm.sample(frac=0.95, random_state=seed)
df_test = df_norm.drop(df_train.index)

df_train_inputs, df_val_inputs, df_train_outputs, df_val_outputs = sklearn.model_selection.train_test_split(df_train[inputs],df_train[outputs], test_size = 0.05, random_state=seed)

print("Training set: ", len(df_train_inputs))
print("Validation set: ", len(df_val_inputs))
print("Test set: ", len(df_test))
# Out:
# Training set:  6754081
# Validation set:  355478
# Test set:  374187

# %% [markdown]
# ## training our network
# here we'll use our *train* and *validation* sets to train our neural network and check for overfitting\
# I'm using the tensorflow functional API here - while this is a little harder to understand than the sequential API, it's more versatile and will let us do fun things like branching the neural network architecture later on!\
# I'll start with a super simple network just to check whether tensorflow is working as intended:

# %%
######## define architecture:
model_name = 'simple_network'
n_dense_layers = 4 #number of dense layers
dense_layer_units = 64 #neurons per dense layer
Nepochs = 5000

###### Checkpointing

checkpoint_dir = f'./chk-{model_name}-nlayers-{n_dense_layers}-nunits-{dense_layer_units}-epochs-{Nepochs}/chk.model.keras'

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_dir, verbose = 1)

######## map out model architecture
#### input layer
nn_input = keras.Input(shape=(len(inputs),))

#### dense layer(s)
for n_dense_layer in range(n_dense_layers):
    if n_dense_layer == 0:
        dense_layer = layers.Dense(dense_layer_units, activation='relu')(nn_input)
    else:
        dense_layer = layers.Dense(dense_layer_units, activation='relu')(dense_layer)

#### output layer
nn_output =  layers.Dense(len(outputs), activation='linear')(dense_layer)

######## store architecture as keras model
model = keras.Model(inputs=nn_input, outputs=nn_output, name=model_name)

tb_callback = tf.keras.callbacks.TensorBoard(log_dir = f'./log-{model_name}-nlayers-{n_dense_layers}-nunits-{dense_layer_units}-epochs-{Nepochs}')

######## plot model
#keras.utils.plot_model(model, "figs/"+model_name+".png", show_layer_activations=True, show_shapes=True, show_layer_names=False)

# %%
######## compile and start training

model.compile(loss='MSE', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

history = model.fit(df_train_inputs,
          df_train_outputs,
          validation_data=(df_val_inputs,df_val_outputs),
          batch_size=10000,
          verbose=1,
          epochs=Nepochs,
          shuffle=True, callbacks = [tb_callback, cp_callback])
# Out:
# Epoch 1/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0204
# Epoch 1: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0204 - val_loss: 0.0136
# Epoch 2/5000
# 1621/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0123
# Epoch 2: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0123 - val_loss: 0.0097
# Epoch 3/5000
# 1619/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0089
# Epoch 3: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0089 - val_loss: 0.0057
# Epoch 4/5000
# 1636/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0064
# Epoch 4: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 5/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0052
# Epoch 5: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0052 - val_loss: 0.0038
# Epoch 6/5000
# 1616/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0046
# Epoch 6: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 7/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0051
# Epoch 7: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0051 - val_loss: 0.0117
# Epoch 8/5000
# 1609/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0046
# Epoch 8: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0046 - val_loss: 0.0033
# Epoch 9/5000
# 1617/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039
# Epoch 9: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0039 - val_loss: 0.0081
# Epoch 10/5000
# 1629/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038
# Epoch 10: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 11/5000
# 1614/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0048
# Epoch 11: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 12/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0035
# Epoch 12: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 13/5000
# 1636/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037
# Epoch 13: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 14/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0036
# Epoch 14: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 15/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0040
# Epoch 15: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 16/5000
# 1617/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057
# Epoch 16: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0057 - val_loss: 0.0023
# Epoch 17/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031
# Epoch 17: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 18/5000
# 1647/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0050
# Epoch 18: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0050 - val_loss: 0.0022
# Epoch 19/5000
# 1643/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028
# Epoch 19: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 20/5000
# 1639/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026
# Epoch 20: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 21/5000
# 1640/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0024
# Epoch 21: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 22/5000
# 1629/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024
# Epoch 22: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 23/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023
# Epoch 23: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 24/5000
# 1636/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 24: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 25/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021
# Epoch 25: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 26/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026
# Epoch 26: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 27/5000
# 1641/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022
# Epoch 27: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 28/5000
# 1609/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022
# Epoch 28: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 29/5000
# 1632/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022
# Epoch 29: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 30/5000
# 1628/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030
# Epoch 30: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 31/5000
# 1648/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 31: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 32/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029
# Epoch 32: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 33/5000
# 1609/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 33: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 34/5000
# 1621/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 34: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0022 - val_loss: 0.0057
# Epoch 35/5000
# 1636/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021
# Epoch 35: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 36/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 36: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0023 - val_loss: 0.0151
# Epoch 37/5000
# 1645/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 37: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 38/5000
# 1628/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020
# Epoch 38: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 39/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021
# Epoch 39: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 40/5000
# 1617/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021
# Epoch 40: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 41/5000
# 1626/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027
# Epoch 41: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0027 - val_loss: 0.0148
# Epoch 42/5000
# 1634/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026
# Epoch 42: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 43/5000
# 1614/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018
# Epoch 43: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 44/5000
# 1614/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0024
# Epoch 44: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 45/5000
# 1640/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 45: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 46/5000
# 1648/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 46: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 47/5000
# 1610/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020
# Epoch 47: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 48/5000
# 1617/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019
# Epoch 48: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 49/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018
# Epoch 49: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 50/5000
# 1616/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019
# Epoch 50: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 51/5000
# 1633/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019
# Epoch 51: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 52/5000
# 1618/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 52: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 53/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019
# Epoch 53: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 54/5000
# 1639/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018
# Epoch 54: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 55/5000
# 1636/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 55: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 56/5000
# 1609/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 56: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 57/5000
# 1618/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019
# Epoch 57: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 58/5000
# 1626/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018
# Epoch 58: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 9.0266e-04
# Epoch 59/5000
# 1620/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 59: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 60/5000
# 1634/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018
# Epoch 60: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0018 - val_loss: 0.0097
# Epoch 61/5000
# 1644/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 61: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0022 - val_loss: 9.5631e-04
# Epoch 62/5000
# 1626/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 62: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 63/5000
# 1613/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018
# Epoch 63: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 64/5000
# 1620/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023
# Epoch 64: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0023 - val_loss: 0.0080
# Epoch 65/5000
# 1624/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019
# Epoch 65: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0019 - val_loss: 8.3360e-04
# Epoch 66/5000
# 1638/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015
# Epoch 66: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 67/5000
# 1640/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015
# Epoch 67: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 68/5000
# 1640/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 68: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 69/5000
# 1638/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014
# Epoch 69: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 70/5000
# 1643/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 70: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0022 - val_loss: 9.4222e-04
# Epoch 71/5000
# 1632/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 71: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 8.1149e-04
# Epoch 72/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 72: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 73/5000
# 1636/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 73: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 74/5000
# 1638/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015
# Epoch 74: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 75/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015
# Epoch 75: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 76/5000
# 1643/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 76: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 77/5000
# 1614/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 77: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0017 - val_loss: 8.2600e-04
# Epoch 78/5000
# 1647/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016
# Epoch 78: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0016 - val_loss: 7.7097e-04
# Epoch 79/5000
# 1633/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014
# Epoch 79: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 80/5000
# 1614/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016
# Epoch 80: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 81/5000
# 1626/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015
# Epoch 81: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0015 - val_loss: 7.5115e-04
# Epoch 82/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 82: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 83/5000
# 1645/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014
# Epoch 83: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 84/5000
# 1643/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018
# Epoch 84: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 85/5000
# 1606/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014
# Epoch 85: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 86/5000
# 1632/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 86: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 87/5000
# 1617/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012
# Epoch 87: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 88/5000
# 1642/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 88: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 89/5000
# 1627/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 89: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0013 - val_loss: 9.1235e-04
# Epoch 90/5000
# 1617/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 90: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 7.7768e-04
# Epoch 91/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 91: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 7.8203e-04
# Epoch 92/5000
# 1628/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014
# Epoch 92: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 93/5000
# 1613/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014
# Epoch 93: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0014 - val_loss: 8.6990e-04
# Epoch 94/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 94: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 7.1913e-04
# Epoch 95/5000
# 1634/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 95: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0013 - val_loss: 6.8170e-04
# Epoch 96/5000
# 1642/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015
# Epoch 96: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0015 - val_loss: 9.0055e-04
# Epoch 97/5000
# 1631/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 97: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 7.4357e-04
# Epoch 98/5000
# 1639/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012
# Epoch 98: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0012 - val_loss: 9.3288e-04
# Epoch 99/5000
# 1618/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012
# Epoch 99: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0012 - val_loss: 8.0214e-04
# Epoch 100/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012
# Epoch 100: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 101/5000
# 1620/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 101: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0011 - val_loss: 8.1662e-04
# Epoch 102/5000
# 1622/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 102: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 103/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 103: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 104/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 104: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 8.1508e-04
# Epoch 105/5000
# 1610/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012
# Epoch 105: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0012 - val_loss: 9.3458e-04
# Epoch 106/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 106: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0011 - val_loss: 8.8807e-04
# Epoch 107/5000
# 1603/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015
# Epoch 107: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0015 - val_loss: 7.2261e-04
# Epoch 108/5000
# 1630/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 108: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0011 - val_loss: 6.1493e-04
# Epoch 109/5000
# 1637/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 109: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 7.0568e-04
# Epoch 110/5000
# 1621/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 110: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 111/5000
# 1647/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015
# Epoch 111: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0015 - val_loss: 6.9096e-04
# Epoch 112/5000
# 1633/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012
# Epoch 112: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0012 - val_loss: 7.0589e-04
# Epoch 113/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 113: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0010 - val_loss: 7.4922e-04
# Epoch 114/5000
# 1614/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 114: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0011 - val_loss: 7.8514e-04
# Epoch 115/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012
# Epoch 115: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 116/5000
# 1618/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 116: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 6.3396e-04
# Epoch 117/5000
# 1638/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 117: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 7.8143e-04
# Epoch 118/5000
# 1627/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 118: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 6.5713e-04
# Epoch 119/5000
# 1635/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 119: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 120/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 120: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0010 - val_loss: 9.2189e-04
# Epoch 121/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8412e-04
# Epoch 121: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.8444e-04 - val_loss: 9.0042e-04
# Epoch 122/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 122: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0010 - val_loss: 9.1444e-04
# Epoch 123/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 123: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 7.0646e-04
# Epoch 124/5000
# 1616/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 124: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0010 - val_loss: 8.5731e-04
# Epoch 125/5000
# 1634/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012
# Epoch 125: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0012 - val_loss: 7.8695e-04
# Epoch 126/5000
# 1640/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8968e-04
# Epoch 126: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.8972e-04 - val_loss: 9.8095e-04
# Epoch 127/5000
# 1628/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8731e-04
# Epoch 127: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.8738e-04 - val_loss: 9.6678e-04
# Epoch 128/5000
# 1645/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 128: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 129/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 129: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 5.4439e-04
# Epoch 130/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 130: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 131/5000
# 1622/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 131: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 7.7307e-04
# Epoch 132/5000
# 1631/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8947e-04
# Epoch 132: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.9003e-04 - val_loss: 5.9651e-04
# Epoch 133/5000
# 1619/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6928e-04
# Epoch 133: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.6916e-04 - val_loss: 8.3267e-04
# Epoch 134/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6821e-04
# Epoch 134: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.6837e-04 - val_loss: 0.0015
# Epoch 135/5000
# 1619/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6154e-04
# Epoch 135: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.6156e-04 - val_loss: 0.0011
# Epoch 136/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6824e-04
# Epoch 136: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.6829e-04 - val_loss: 8.9503e-04
# Epoch 137/5000
# 1609/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9235e-04
# Epoch 137: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.9481e-04 - val_loss: 5.3953e-04
# Epoch 138/5000
# 1604/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4168e-04
# Epoch 138: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.4318e-04 - val_loss: 0.0012
# Epoch 139/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 139: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0011 - val_loss: 6.2051e-04
# Epoch 140/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 140: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 141/5000
# 1631/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7354e-04
# Epoch 141: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.7417e-04 - val_loss: 6.6630e-04
# Epoch 142/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1445e-04
# Epoch 142: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.1484e-04 - val_loss: 5.5892e-04
# Epoch 143/5000
# 1637/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9116e-04
# Epoch 143: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.9122e-04 - val_loss: 5.5033e-04
# Epoch 144/5000
# 1630/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4503e-04
# Epoch 144: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.4552e-04 - val_loss: 6.4829e-04
# Epoch 145/5000
# 1624/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2426e-04
# Epoch 145: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.2442e-04 - val_loss: 0.0012
# Epoch 146/5000
# 1642/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 146: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0010 - val_loss: 5.6043e-04
# Epoch 147/5000
# 1636/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 147: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0010 - val_loss: 6.7765e-04
# Epoch 148/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2948e-04
# Epoch 148: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.2946e-04 - val_loss: 9.2872e-04
# Epoch 149/5000
# 1640/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 149: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 5.2938e-04
# Epoch 150/5000
# 1621/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1026e-04
# Epoch 150: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 9.1038e-04 - val_loss: 8.2813e-04
# Epoch 151/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4697e-04
# Epoch 151: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.4855e-04 - val_loss: 0.0015
# Epoch 152/5000
# 1622/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4375e-04
# Epoch 152: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 9.4436e-04 - val_loss: 7.3232e-04
# Epoch 153/5000
# 1643/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3112e-04
# Epoch 153: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3147e-04 - val_loss: 9.6198e-04
# Epoch 154/5000
# 1630/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9648e-04
# Epoch 154: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.9677e-04 - val_loss: 7.2040e-04
# Epoch 155/5000
# 1644/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4153e-04
# Epoch 155: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.4159e-04 - val_loss: 5.5053e-04
# Epoch 156/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5757e-04
# Epoch 156: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.5674e-04 - val_loss: 0.0014
# Epoch 157/5000
# 1631/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1620e-04
# Epoch 157: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.1610e-04 - val_loss: 6.2543e-04
# Epoch 158/5000
# 1635/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 158: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0011 - val_loss: 6.4918e-04
# Epoch 159/5000
# 1632/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7033e-04
# Epoch 159: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.7036e-04 - val_loss: 9.7267e-04
# Epoch 160/5000
# 1609/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7259e-04
# Epoch 160: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.7216e-04 - val_loss: 5.0169e-04
# Epoch 161/5000
# 1630/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6430e-04
# Epoch 161: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.6443e-04 - val_loss: 8.4557e-04
# Epoch 162/5000
# 1606/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 162: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0010 - val_loss: 5.2664e-04
# Epoch 163/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2345e-04
# Epoch 163: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.2459e-04 - val_loss: 0.0013
# Epoch 164/5000
# 1635/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9313e-04
# Epoch 164: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.9323e-04 - val_loss: 6.6550e-04
# Epoch 165/5000
# 1621/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1361e-04
# Epoch 165: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.1327e-04 - val_loss: 0.0013
# Epoch 166/5000
# 1648/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3084e-04
# Epoch 166: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3088e-04 - val_loss: 0.0028
# Epoch 167/5000
# 1632/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 167: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0011 - val_loss: 7.0938e-04
# Epoch 168/5000
# 1609/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3429e-04
# Epoch 168: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.3427e-04 - val_loss: 8.0843e-04
# Epoch 169/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3322e-04
# Epoch 169: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.3321e-04 - val_loss: 9.8340e-04
# Epoch 170/5000
# 1638/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8772e-04
# Epoch 170: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.8814e-04 - val_loss: 7.9556e-04
# Epoch 171/5000
# 1609/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5100e-04
# Epoch 171: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.5176e-04 - val_loss: 5.3387e-04
# Epoch 172/5000
# 1613/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.4555e-04
# Epoch 172: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.4581e-04 - val_loss: 7.6508e-04
# Epoch 173/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6345e-04
# Epoch 173: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.6343e-04 - val_loss: 0.0015
# Epoch 174/5000
# 1614/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 174: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0010 - val_loss: 6.4816e-04
# Epoch 175/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9550e-04
# Epoch 175: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.9552e-04 - val_loss: 7.8882e-04
# Epoch 176/5000
# 1648/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5884e-04
# Epoch 176: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.5884e-04 - val_loss: 7.8627e-04
# Epoch 177/5000
# 1606/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 177: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 178/5000
# 1635/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3758e-04
# Epoch 178: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.3749e-04 - val_loss: 0.0024
# Epoch 179/5000
# 1641/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3402e-04
# Epoch 179: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3424e-04 - val_loss: 4.9827e-04
# Epoch 180/5000
# 1630/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5393e-04
# Epoch 180: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.5473e-04 - val_loss: 5.7877e-04
# Epoch 181/5000
# 1627/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9430e-04
# Epoch 181: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.9497e-04 - val_loss: 4.7802e-04
# Epoch 182/5000
# 1624/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5626e-04
# Epoch 182: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.5644e-04 - val_loss: 5.2086e-04
# Epoch 183/5000
# 1629/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1145e-04
# Epoch 183: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 9.1119e-04 - val_loss: 5.9076e-04
# Epoch 184/5000
# 1622/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3181e-04
# Epoch 184: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.3274e-04 - val_loss: 9.0146e-04
# Epoch 185/5000
# 1627/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.7756e-04
# Epoch 185: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.7776e-04 - val_loss: 5.6350e-04
# Epoch 186/5000
# 1634/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3589e-04
# Epoch 186: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.3640e-04 - val_loss: 0.0012
# Epoch 187/5000
# 1641/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.4144e-04
# Epoch 187: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.4196e-04 - val_loss: 5.8314e-04
# Epoch 188/5000
# 1630/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1036e-04
# Epoch 188: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.1082e-04 - val_loss: 0.0012
# Epoch 189/5000
# 1642/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1321e-04
# Epoch 189: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.1326e-04 - val_loss: 4.8308e-04
# Epoch 190/5000
# 1638/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5222e-04
# Epoch 190: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.5248e-04 - val_loss: 9.4114e-04
# Epoch 191/5000
# 1623/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6554e-04
# Epoch 191: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.6605e-04 - val_loss: 5.8127e-04
# Epoch 192/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2849e-04
# Epoch 192: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 8.2905e-04 - val_loss: 4.9459e-04
# Epoch 193/5000
# 1624/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6504e-04
# Epoch 193: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# ...
# Epoch 534: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9659e-04 - val_loss: 3.9605e-04
# Epoch 535/5000
# 1641/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1059e-04
# Epoch 535: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.1054e-04 - val_loss: 3.0832e-04
# Epoch 536/5000
# 1647/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0626e-04
# Epoch 536: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.0626e-04 - val_loss: 4.2664e-04
# Epoch 537/5000
# 1632/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0085e-04
# Epoch 537: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.0079e-04 - val_loss: 5.1323e-04
# Epoch 538/5000
# 1626/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2515e-04
# Epoch 538: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.2494e-04 - val_loss: 4.2323e-04
# Epoch 539/5000
# 1616/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9580e-04
# Epoch 539: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.9586e-04 - val_loss: 6.7071e-04
# Epoch 540/5000
# 1611/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0478e-04
# Epoch 540: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.0473e-04 - val_loss: 6.0603e-04
# Epoch 541/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9652e-04
# Epoch 541: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9660e-04 - val_loss: 5.3795e-04
# Epoch 542/5000
# 1600/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0265e-04
# Epoch 542: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.0251e-04 - val_loss: 2.9906e-04
# Epoch 543/5000
# 1638/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9810e-04
# Epoch 543: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.9816e-04 - val_loss: 3.2240e-04
# Epoch 544/5000
# 1620/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9414e-04
# Epoch 544: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9417e-04 - val_loss: 5.9888e-04
# Epoch 545/5000
# 1628/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0552e-04
# Epoch 545: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.0542e-04 - val_loss: 5.7427e-04
# Epoch 546/5000
# 1647/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9897e-04
# Epoch 546: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.9897e-04 - val_loss: 3.5568e-04
# Epoch 547/5000
# 1608/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8484e-04
# Epoch 547: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8503e-04 - val_loss: 3.5129e-04
# Epoch 548/5000
# 1614/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0347e-04
# Epoch 548: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.0347e-04 - val_loss: 5.6155e-04
# Epoch 549/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9708e-04
# Epoch 549: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9708e-04 - val_loss: 3.5611e-04
# Epoch 550/5000
# 1629/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8991e-04
# Epoch 550: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8990e-04 - val_loss: 2.7930e-04
# Epoch 551/5000
# 1633/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0942e-04
# Epoch 551: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.0933e-04 - val_loss: 3.4450e-04
# Epoch 552/5000
# 1601/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9355e-04
# Epoch 552: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9364e-04 - val_loss: 2.7771e-04
# Epoch 553/5000
# 1628/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9922e-04
# Epoch 553: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.9927e-04 - val_loss: 4.1523e-04
# Epoch 554/5000
# 1613/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9823e-04
# Epoch 554: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9810e-04 - val_loss: 7.9578e-04
# Epoch 555/5000
# 1605/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0229e-04
# Epoch 555: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.0228e-04 - val_loss: 4.0148e-04
# Epoch 556/5000
# 1644/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8627e-04
# Epoch 556: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8628e-04 - val_loss: 2.9684e-04
# Epoch 557/5000
# 1647/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9459e-04
# Epoch 557: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.9459e-04 - val_loss: 9.1583e-04
# Epoch 558/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9712e-04
# Epoch 558: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.9701e-04 - val_loss: 4.2702e-04
# Epoch 559/5000
# 1622/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8075e-04
# Epoch 559: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.8084e-04 - val_loss: 0.0010
# Epoch 560/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1217e-04
# Epoch 560: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.1215e-04 - val_loss: 3.3571e-04
# Epoch 561/5000
# 1606/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8363e-04
# Epoch 561: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8382e-04 - val_loss: 4.2603e-04
# Epoch 562/5000
# 1615/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8899e-04
# Epoch 562: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.8903e-04 - val_loss: 3.1679e-04
# Epoch 563/5000
# 1613/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9323e-04
# Epoch 563: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9320e-04 - val_loss: 2.9803e-04
# Epoch 564/5000
# 1646/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7951e-04
# Epoch 564: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.7954e-04 - val_loss: 4.5211e-04
# Epoch 565/5000
# 1639/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9277e-04
# Epoch 565: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9273e-04 - val_loss: 4.0890e-04
# Epoch 566/5000
# 1633/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9649e-04
# Epoch 566: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9647e-04 - val_loss: 7.0898e-04
# Epoch 567/5000
# 1643/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9605e-04
# Epoch 567: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9605e-04 - val_loss: 8.8471e-04
# Epoch 568/5000
# 1610/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7965e-04
# Epoch 568: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.7978e-04 - val_loss: 3.1649e-04
# Epoch 569/5000
# 1619/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8649e-04
# Epoch 569: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8656e-04 - val_loss: 3.9644e-04
# Epoch 570/5000
# 1647/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9843e-04
# Epoch 570: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9842e-04 - val_loss: 4.4042e-04
# Epoch 571/5000
# 1612/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8177e-04
# Epoch 571: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8191e-04 - val_loss: 5.8474e-04
# Epoch 572/5000
# 1639/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8556e-04
# Epoch 572: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.8555e-04 - val_loss: 3.0428e-04
# Epoch 573/5000
# 1601/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9329e-04
# Epoch 573: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9324e-04 - val_loss: 3.4889e-04
# Epoch 574/5000
# 1640/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8370e-04
# Epoch 574: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8370e-04 - val_loss: 6.8783e-04
# Epoch 575/5000
# 1637/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9142e-04
# Epoch 575: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9139e-04 - val_loss: 3.2215e-04
# Epoch 576/5000
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8213e-04
# Epoch 576: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8213e-04 - val_loss: 4.4540e-04
# Epoch 577/5000
# 1618/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9346e-04
# Epoch 577: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9338e-04 - val_loss: 5.1504e-04
# Epoch 578/5000
# 1628/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7644e-04
# Epoch 578: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.7651e-04 - val_loss: 6.0152e-04
# Epoch 579/5000
# 1642/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8135e-04
# Epoch 579: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.8134e-04 - val_loss: 3.9529e-04
# Epoch 580/5000
# 1618/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9793e-04
# Epoch 580: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9782e-04 - val_loss: 4.5886e-04
# Epoch 581/5000
# 1639/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6847e-04
# Epoch 581: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.6856e-04 - val_loss: 3.9979e-04
# Epoch 582/5000
# 1639/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8718e-04
# Epoch 582: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.8715e-04 - val_loss: 6.7692e-04
# Epoch 583/5000
# 1648/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8579e-04
# Epoch 583: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.8579e-04 - val_loss: 6.1732e-04
# Epoch 584/5000
# 1632/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8611e-04
# Epoch 584: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8606e-04 - val_loss: 4.3449e-04
# Epoch 585/5000
# 1613/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8374e-04
# Epoch 585: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8388e-04 - val_loss: 3.0835e-04
# Epoch 586/5000
# 1625/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6826e-04
# Epoch 586: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.6838e-04 - val_loss: 4.8176e-04
# Epoch 587/5000
# 1641/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7556e-04
# Epoch 587: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.7558e-04 - val_loss: 4.0055e-04
# Epoch 588/5000
# 1638/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8178e-04
# Epoch 588: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8177e-04 - val_loss: 5.1379e-04
# Epoch 589/5000
# 1625/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8808e-04
# Epoch 589: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8804e-04 - val_loss: 3.9097e-04
# Epoch 590/5000
# 1630/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7367e-04
# Epoch 590: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.7377e-04 - val_loss: 7.1979e-04
# Epoch 591/5000
# 1639/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7010e-04
# Epoch 591: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.7014e-04 - val_loss: 4.6298e-04
# Epoch 592/5000
# 1623/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9680e-04
# Epoch 592: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.9655e-04 - val_loss: 2.8466e-04
# Epoch 593/5000
# 1616/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7946e-04
# Epoch 593: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.7950e-04 - val_loss: 0.0014
# Epoch 594/5000
# 1623/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8723e-04
# Epoch 594: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8709e-04 - val_loss: 2.9822e-04
# Epoch 595/5000
# 1645/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8610e-04
# Epoch 595: saving model to ./chk-simple_network-nlayers-4-nunits-64-epochs-5000/chk.model.keras
# 1649/1649 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.8609e-04 - val_loss: 5.4425e-04
# Epoch 596/5000
# 1150/1649 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7887e-04

# %% [markdown]
# ## testing the network
# this section is very rushed, the main thing is to remember to rescale your data (as the network will predict in the normalised space), and to predict on the test set that was taken out of the dataset before training!

# %%
def unnorm(df_norm, df_min, df_max):
    df_unnorm = (df_norm*(df_max-df_min)) + df_min
    return df_unnorm

preds_norm = model(np.array(df_test[inputs]))

df_preds_norm = pd.DataFrame(preds_norm, columns=outputs)
df_preds_unnorm = unnorm(df_preds_norm, df[outputs].min(), df[outputs].max())

df_test_unnorm = unnorm(df_test, df.min(), df.max())

# %%
def get_norm_track(massini = 1.0, approxzini = 0.005, df = df):
    
    # This is my dumb function for pulling tracks with a set mass and metallicity and then normalizing 
    
    normmass = (massini - df['massini'].min())/(df['massini'].max() - df['massini'].min())

    normzini = (approxzini - df['zini'].min())/(df['zini'].max() - df['zini'].min())
    
    massselect = df_norm[df_norm['massini'] == normmass]
    
    massselect['zdiff'] = np.abs(massselect['zini'] - normzini)
    
    return massselect[massselect['zini'] == massselect.loc[massselect[['zdiff']].idxmin(), 'zini'].values[0]].drop('zdiff', axis = 1)

def get_preds_track(norm_track, inputs, outputs, df = df):

    pred_track_norm = pd.DataFrame(model(np.array(norm_track[inputs])), columns = outputs)

    return unnorm(pred_track_norm, df[outputs].min(), df[outputs].max())

# %%
masses = [0.7, 1.0, 1.5]
colors = ['blue', 'red', 'green']

fig = plt.figure(figsize = (5, 8))
for i in range(len(masses)):
    test_track_norm = get_norm_track(massini = masses[i])

    test_track = unnorm(test_track_norm, df.min(), df.max())

    preds_test_track = get_preds_track(test_track_norm, inputs, outputs)

    plt.semilogy(test_track['Teff'], test_track['LPhot'], color = colors[i], linestyle = '--', label = f'{masses[i]}')
    plt.semilogy(preds_test_track['Teff'], preds_test_track['LPhot'], color = colors[i])
plt.gca().invert_xaxis()
plt.legend()
plt.ylabel(r'Luminosity [L$_{\odot}$]')
plt.xlabel(r'$T_{\mathrm{eff}}$ [K]')
# Out:
# /tmp/ipykernel_306918/3962967233.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   massselect['zdiff'] = np.abs(massselect['zini'] - normzini)
# /tmp/ipykernel_306918/3962967233.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   massselect['zdiff'] = np.abs(massselect['zini'] - normzini)
# /tmp/ipykernel_306918/3962967233.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   massselect['zdiff'] = np.abs(massselect['zini'] - normzini)
# Text(0.5, 0, '$T_{\\mathrm{eff}}$ [K]')

# %%
figure = corner.corner(df_test_unnorm[outputs])
corner.corner(df_preds_unnorm, color='red', fig=figure);
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
plt.scatter(df_test_unnorm['Teff'], np.log10(df_test_unnorm['LPhot']), alpha = 0.1, edgecolor = 'None')
plt.scatter(df_preds_unnorm['Teff'], np.log10(df_preds_unnorm['LPhot']), alpha = 0.1, edgecolor = 'None')
plt.gca().invert_xaxis()
# Out:
# /home/hatte/miniconda3/envs/py312-nn/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
